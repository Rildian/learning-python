# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('AirPassengers.csv')

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.set_index("Month").plot()
# Out:
# <Axes: xlabel='Month'>

# %%
df.plot(x="Month")
# Out:
# <Axes: xlabel='Month'>

# %%
df.set_index("Month").loc["1949-01":"1949-12"].plot()
# Out:
# <Axes: xlabel='Month'>
